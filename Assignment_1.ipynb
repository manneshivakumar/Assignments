# %%
# Task 1:
# Problem 1:

# %% [markdown]
# Screenshot 2020-03-17 at 3.58.13 PM![image.png](attachment:image.png)

# %%
# Task 1: 
# Problem 2:

for i in range(2000, 3201):
    if (i % 7 == 0 ) and (i % 5 != 0):
        print(i, end =',')
# Out:
# 2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199,

# %%
# Task 1: 
# Problem 3:

f_name = input("enter first name : ")
l_name = input("enter last name : ")
a,b = reversed(f_name) , reversed(l_name)
str1 = ''.join((list(a) + list(" ") + list(b)))
print(str1)
# Out:
# enter first name : shiva
# enter last name : kumar
# avihs ramuk

# %%
# Task 1: 
# Problem 4:

d = 12
V = (4/3)*(22/7)*(d/2)*(d/2)*(d/2)
print("Volume = ", V)
# Out:
# Volume =  905.142857142857

# %%
# Task 2:
# Problem 1:

ip = input("enter some , separated values : ")
print(list(ip.split()))
# Out:
# enter some , separated values : 1,2,3,4
# ['1,2,3,4']

# %%
#T ask 2: 
# Problem 2:
# Min = starting/ending length; Max = maximum length
Min, Max = 1, 5

while Min <= Max:
    print('*' * Min)
    Min = Min + 1
while Min > 0:
    print('*' * Min)
    Min = Min - 1
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *****
# ****
# ***
# **
# *

# %%
# Task 2: 
# Problem 3:
in_put = input("enter any string : ")
str1 = ''.join(list(reversed(in_put)))
print(str1)
#print(in_put[::-1])
# Out:
# enter any string : SqAwSSSaQSa
# aSQaSSSwAqS

# %%
# Task 2: 
# Problem 4:
print("""WE, THE PEOPLE OF INDIA,\n\thaving solemnly resolved to constitute India into a SOVEREIGN,!\n\t\tSOCIALIST, SECULAR, DEMOCRATIC REPUBLIC \n\t\tand to secure to all its citizens""")
# Out:
# WE, THE PEOPLE OF INDIA,
# 	having solemnly resolved to constitute India into a SOVEREIGN,!
# 		SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
# 		and to secure to all its citizens
